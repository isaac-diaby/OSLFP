# %%
import cv2 as cv
import numpy as np 
from matplotlib import pyplot as plt

# %%
def showimage(image):
     # OpenCV opens images as BRG
    img_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)
    plt.imshow(img_rgb)

# %% [markdown]
# # test 1

# %%
#load image and convert to hsv
img = cv.imread("./testing/cameras/2.png")
showimage(img)

# %%
# derive the paths to the YOLO weights and model configuration
weightsPath = "yolov5/runs/train/exp6/weights/best.pt"
configPath = os.path.sep.join([args["yolo"], "yolov3.cfg"])
# init lists of bounding box coordinates, confidences, and class IDs
boxes = []
confidences = []
classIDs = []

# %%
frame_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
frame_gray = cv.equalizeHist(frame_gray)
showimage(frame_gray)
